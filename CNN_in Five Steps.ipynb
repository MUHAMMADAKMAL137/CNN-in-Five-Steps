# %%
import numpy as np
from numpy import asarray

# %%
data = [[3,3,2,1,0],
        [0,0,1,3,1],
        [3,1,2,2,3],
        [2,0,0,2,2],
        [2,0,0,0,1],]
        #the variable data is a 2D list representing a matrix with 5 rows and 5 columns, where each element contains integer values ranging from 0 to 3.

# %%
data = np.asarray(data)
data =data.reshape(1,5,5,1)
#the variable data is converted to a NumPy array using np.asarray(), and then it is reshaped to a 4-dimensional array with a shape of (1, 5, 5, 1), representing a single grayscale image of size 5x5.

# %%
kernel = [[[[0]], [[1]], [[2]]],
          [[[2]], [[2]], [[0]]],
          [[[0]], [[1]], [[2]]]]
          #the variable kernel is a 4-dimensional list representing a 3x3 filter with a depth of 1, used for convolutional operations in a deep learning model.

# %%
weights = [asarray(kernel), asarray([0.0])]
#the variable weights is a list containing two elements: the first element is a NumPy array kernel, and the second element is a NumPy array with a single value 0.0, which could be used as weights in a neural network layer.

# %%
from google.colab import files
from IPython.display import Image
#the libraries files from google.colab and Image from IPython.display are imported, allowing you to upload files and display images in a Google Colab notebook, respectively.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-92bd880f-71cd-4ded-9e1c-1856101cb5a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92bd880f-71cd-4ded-9e1c-1856101cb5a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Screenshot_1.png', width=600)

# %%
from keras.models import Sequential
from keras.layers import Conv2D

# %%
model = Sequential()
model.add(Conv2D(1,(3,3), input_shape=(5,5,1)))
model.summary()
#a sequential model is initialized, followed by adding a 2D convolutional layer with 1 filter and a kernel size of (3,3), taking input with a shape of (5,5,1), and finally, the model summary is displayed.
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 3, 3, 1)           10
#
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.set_weights(weights)
yhat= model.predict(data)
for r in range (yhat.shape[1]):
  print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
  #the pre-defined weights are set to the model, then using the input data, predictions are made using the model, and the output predictions for each row are printed in a formatted way.
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [12.0, 12.0, 17.0]
# [10.0, 17.0, 19.0]
# [9.0, 6.0, 14.0]

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4a8dd78b-b306-4d36-b859-54afc6a8b2b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a8dd78b-b306-4d36-b859-54afc6a8b2b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Screenshot_4.png', width =600)

# %%
model = Sequential()
model.add(Conv2D(1,(3,3), strides = (2,2),input_shape=(5,5,1)))
#a 2D convolutional layer with 1 filter and a kernel size of (3,3) is added to the model, using a stride of (2,2), and taking input with a shape of (5,5,1).
model.summary()
model.set_weights(weights)
yhat= model.predict(data)
for r in range (yhat.shape[1]):
  print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_1 (Conv2D)           (None, 2, 2, 1)           10
#
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 33ms/step
# [12.0, 17.0]
# [9.0, 14.0]

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-60f238ac-c800-44e3-bf42-c6bb36c00b47" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60f238ac-c800-44e3-bf42-c6bb36c00b47">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Screenshot_6.png', width = 600)

# %%
model = Sequential()
model.add(Conv2D(1,(3,3), padding = 'same',input_shape=(5,5,1)))
#a 2D convolutional layer with 1 filter and a kernel size of (3,3) is added to the model, using 'same' padding, and taking input with a shape of (5,5,1).
model.summary()
model.set_weights(weights)
yhat= model.predict(data)
for r in range (yhat.shape[1]):
  print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 5, 5, 1)           10
#
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 32ms/step
# [6.0, 14.0, 17.0, 11.0, 3.0]
# [14.0, 12.0, 12.0, 17.0, 11.0]
# [8.0, 10.0, 17.0, 19.0, 13.0]
# [11.0, 9.0, 6.0, 14.0, 12.0]
# [6.0, 4.0, 4.0, 6.0, 4.0]

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a31a04c8-9448-4ea9-a75f-831ed83ef8a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a31a04c8-9448-4ea9-a75f-831ed83ef8a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Screenshot_7.png', width =600)

# %%
from keras.layers.pooling.max_pooling2d import MaxPool2D
model = Sequential()
model.add(Conv2D(1,(3,3), padding = 'same',input_shape=(5,5,1)))
model.add(MaxPool2D((2,2)))
#a 2D max-pooling layer with a pool size of (2,2) is added to the model, reducing the spatial dimensions of the input data by a factor of 2 in both height and width.
model.summary()
model.set_weights(weights)
yhat= model.predict(data)
for r in range (yhat.shape[1]):
  print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 5, 5, 1)           10
#
#  max_pooling2d (MaxPooling2D  (None, 2, 2, 1)          0
#  )
#
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 53ms/step
# [14.0, 17.0]
# [11.0, 19.0]

# %%
uplaoded = files.upload()
# Out:
#      <input type="file" id="files-af6dd3e4-5362-43fe-ae81-0cc9457808a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af6dd3e4-5362-43fe-ae81-0cc9457808a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Screenshot_8.png', width = 600)

# %%
from keras.layers.pooling.average_pooling2d import AveragePooling2D
from keras.layers.pooling.max_pooling2d import MaxPool2D
model = Sequential()
model.add(Conv2D(1,(3,3), padding = 'same',input_shape=(5,5,1)))
model.add(AveragePooling2D((2,2)))
#a 2D Avg-pooling layer with a pool size of (2,2) is added to the model, reducing the spatial dimensions of the input data by a factor of 2 in both height and width.
model.summary()
model.set_weights(weights)
yhat= model.predict(data)
for r in range (yhat.shape[1]):
  print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_10 (Conv2D)          (None, 5, 5, 1)           10
#
#  average_pooling2d (AverageP  (None, 2, 2, 1)          0
#  ooling2D)
#
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53914977-bfdc-4dde-b478-8f44d6133ef6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53914977-bfdc-4dde-b478-8f44d6133ef6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Screenshot_9.png', width = 600)

# %%
from keras.layers import Flatten
from keras.layers.pooling.max_pooling2d import MaxPool2D
model = Sequential()
model.add(Conv2D(1,(3,3), padding = 'same',input_shape=(5,5,1)))
model.add(MaxPool2D((2,2)))
model.add(Flatten())
# 2D convolutional layer with 1 filter and a kernel size of (3,3) is added to the model with 'same' padding and taking input with a shape of (5,5,1). Then, a 2D max-pooling layer with a pool size of (2,2) is added to the model, followed by a flatten layer to transform the multi-dimensional output into a one-dimensional vector.
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_13 (Conv2D)          (None, 5, 5, 1)           10
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 1)          0
#  2D)
#
#  flatten (Flatten)           (None, 4)                 0
#
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
